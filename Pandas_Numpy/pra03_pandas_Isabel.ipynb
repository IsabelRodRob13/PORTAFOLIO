# %% [markdown]
# # Programación 201

# %% [markdown]
# Librerías científicas en Python: `Pandas`
# ------------------------------------------------------

# %% [markdown]
# ### Ejercicio 1
#
# Cargad los datos del fichero _got.csv_ en un _dataframe_. Este conjunto de datos recoge información de la [Guerra de los Cinco Reyes](https://awoiaf.westeros.org/index.php/War_of_the_Five_Kings) de las novelas de [Cancion de Hielo y Fuego](https://es.wikipedia.org/wiki/Canci%C3%B3n_de_hielo_y_fuego) de George R.R Martin.
#
# Mostrad el número de filas del _dataframe_ y las etiquetas de los ejes.

# %%
import pandas as pd
import numpy as np

# %%
Ruta_fichero= "https://raw.githubusercontent.com/marcusRB/The_Bridge_School_DataScience_PT/main/02_DataAnalysis/dataset/got.csv"
Guerra_Cinco_Reyes=pd.read_csv(Ruta_fichero)
Guerra_Cinco_Reyes
# Out:
#                                                  name  ...                                               note
# 0                          Battle of the Golden Tooth  ...                                                NaN
# 1                         Battle at the Mummer's Ford  ...                                                NaN
# 2                                  Battle of Riverrun  ...                                                NaN
# 3                            Battle of the Green Fork  ...                                                NaN
# 4                       Battle of the Whispering Wood  ...                                                NaN
# 5                                 Battle of the Camps  ...                                                NaN
# 6                                       Sack of Darry  ...                                                NaN
# 7                               Battle of Moat Cailin  ...                                                NaN
# 8                            Battle of Deepwood Motte  ...                                                NaN
# 9                           Battle of the Stony Shore  ...  Greyjoy's troop number based on the Battle of ...
# 10                         Battle of Torrhen's Square  ...  Greyjoy's troop number comes from the 264 esti...
# 11                               Battle of Winterfell  ...  It isn't mentioned how many Stark men are left...
# 12                           Sack of Torrhen's Square  ...                                                NaN
# 13                                 Sack of Winterfell  ...  Since House Bolton betrays the Starks for Hous...
# 14                                  Battle of Oxcross  ...                                                NaN
# 15                               Siege of Storm's End  ...                                                NaN
# 16                                Battle of the Fords  ...                                                NaN
# 17                                  Sack of Harrenhal  ...                                                NaN
# 18                                 Battle of the Crag  ...                                                NaN
# 19                           Battle of the Blackwater  ...                                                NaN
# 20                                     Siege of Darry  ...                                                NaN
# 21                               Battle of Duskendale  ...                                                NaN
# 22                       Battle of the Burning Septry  ...                                                NaN
# 23                            Battle of the Ruby Ford  ...                                                NaN
# 24                              Retaking of Harrenhal  ...                                                NaN
# 25                                    The Red Wedding  ...  This observation refers to the battle against ...
# 26                                   Siege of Seagard  ...                                                NaN
# 27                             Battle of Castle Black  ...                                                NaN
# 28                                Fall of Moat Cailin  ...                                                NaN
# 29                                   Sack of Saltpans  ...                                                NaN
# 30                         Retaking of Deepwood Motte  ...                                                NaN
# 31                       Battle of the Shield Islands  ...                                                NaN
# 32  Invasion of Ryamsport, Vinetown, and Starfish ...  ...                                                NaN
# 33                        Second Seige of Storm's End  ...                                                NaN
# 34                               Siege of Dragonstone  ...                                                NaN
# 35                                  Siege of Riverrun  ...                                                NaN
# 36                                 Siege of Raventree  ...                                                NaN
# 37                                Siege of Winterfell  ...                                                NaN
#
# [38 rows x 25 columns]

# %%
Guerra_Cinco_Reyes.head(5)
# Out:
#                             name  year  ...           region note
# 0     Battle of the Golden Tooth   298  ...  The Westerlands  NaN
# 1    Battle at the Mummer's Ford   298  ...   The Riverlands  NaN
# 2             Battle of Riverrun   298  ...   The Riverlands  NaN
# 3       Battle of the Green Fork   298  ...   The Riverlands  NaN
# 4  Battle of the Whispering Wood   298  ...   The Riverlands  NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Ejercicio 2
#
# Agrupad los datos cargados en el ejercicio 1 por el principal bando atacante (*attacker\_1*). Para cada posición, mostrad el número de batallas y el resultado de la batalla (el resultado se encuentra en el campo *attacker\_outcome*).

# %%
df1=Guerra_Cinco_Reyes.groupby(['battle_number','attacker_outcome'])['attacker_1'].count()
df1
# Out:
# battle_number  attacker_outcome
# 1              win                 1
# 2              win                 1
# 3              win                 1
# 4              loss                1
# 5              win                 1
# 6              win                 1
# 7              win                 1
# 8              win                 1
# 9              win                 1
# 10             win                 1
# 11             win                 1
# 12             win                 1
# 13             win                 1
# 14             win                 1
# 15             win                 1
# 16             win                 1
# 17             loss                1
# 18             win                 1
# 19             win                 1
# 20             loss                1
# 21             win                 1
# 22             loss                1
# 23             win                 1
# 24             win                 1
# 25             win                 1
# 26             win                 1
# 27             win                 1
# 28             loss                1
# 29             win                 1
# 30             win                 1
# 31             win                 1
# 32             win                 1
# 33             win                 1
# 34             win                 1
# 35             win                 1
# 36             win                 1
# 37             win                 1
# Name: attacker_1, dtype: int64

# %% [markdown]
# ### Ejercicio 3
#
# Mostrad los datos de las batallas donde el numero de participantes supera los 15000 "hombres" (contando ambos bandos: *attacker\_size* y *defender\_size*), el resultado haya sido favorable para el atacante, y la batalla se haya producido en invierno (_summer=0_).

# %%
dfx=Guerra_Cinco_Reyes[Guerra_Cinco_Reyes["attacker_size"]>1500 ][Guerra_Cinco_Reyes["defender_size"]>1500 ][Guerra_Cinco_Reyes["attacker_outcome"]=="win" ]
dfx
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                              name  ...                                               note
# 0      Battle of the Golden Tooth  ...                                                NaN
# 2              Battle of Riverrun  ...                                                NaN
# 4   Battle of the Whispering Wood  ...                                                NaN
# 5             Battle of the Camps  ...                                                NaN
# 14              Battle of Oxcross  ...                                                NaN
# 15           Siege of Storm's End  ...                                                NaN
# 25                The Red Wedding  ...  This observation refers to the battle against ...
#
# [7 rows x 25 columns]

# %%
Guerra_Cinco_Reyes['attacker_size'] = Guerra_Cinco_Reyes['attacker_size'].replace(np.nan, 0)
df2=Guerra_Cinco_Reyes[Guerra_Cinco_Reyes["attacker_size"]>1500 ][Guerra_Cinco_Reyes["defender_size"]>1500 ][Guerra_Cinco_Reyes["attacker_outcome"]=="win" ][Guerra_Cinco_Reyes["summer"]== 0 ]
df2
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# Empty DataFrame
# Columns: [name, year, battle_number, attacker_king, defender_king, attacker_1, attacker_2, attacker_3, attacker_4, defender_1, defender_2, defender_3, defender_4, attacker_outcome, battle_type, major_death, major_capture, attacker_size, defender_size, attacker_commander, defender_commander, summer, location, region, note]
# Index: []

# %% [markdown]
# ## Reemplazar valores nulos.

# %%
Guerra_Cinco_Reyes['attacker_size'] = Guerra_Cinco_Reyes['attacker_size'].fillna(0)

# %%
Guerra_Cinco_Reyes['attacker_size'] = Guerra_Cinco_Reyes['attacker_size'].replace(np.nan, 0)

# %% [markdown]
# ### Ejercicio 4
#
# Contad el número de lugares que aparecen más de una vez en _dataframe_ (campo _location_), utilizando las funciones de la librería _pandas_. ¿Existe algún lugar donde se haya realizado más de una batalla? Comprobad qué bandos estaban implicados.

# %%
Guerra_Cinco_Reyes.groupby("location")["location"].count()
# Out:
# location
# Castle Black                            1
# Crag                                    1
# Darry                                   2
# Deepwood Motte                          2
# Dragonstone                             1
# Duskendale                              1
# Golden Tooth                            1
# Green Fork                              1
# Harrenhal                               2
# King's Landing                          1
# Moat Cailin                             2
# Mummer's Ford                           1
# Oxcross                                 1
# Raventree                               1
# Red Fork                                1
# Riverrun                                3
# Ruby Ford                               1
# Ryamsport, Vinetown, Starfish Harbor    1
# Saltpans                                1
# Seagard                                 1
# Shield Islands                          1
# Stony Shore                             1
# Storm's End                             2
# The Twins                               1
# Torrhen's Square                        2
# Whispering Wood                         1
# Winterfell                              3
# Name: location, dtype: int64

# %% [markdown]
# ### Ejercicio 5
#
# Añadid una nueva columna al _dataframe_ con un valor booleano indicando una predicción básica de si en una cierta batalla el bando atacante será vencedor. Definiremos el valor como _True_ sí el bando atacante es mayor al defensor, y como _False_ en caso contrario. Definid como _NaN_ aquellos casos en los que no haya número de tropas en ningún bando. ¿En que casos, identificados por el número de batalla (*battle\_number*), nuestra predicción coincide con el resultado real?

# %%
new_colum=[
           (Guerra_Cinco_Reyes["attacker_outcome"]== "win")
           ]    
new_colum
# Out:
# [0      True
#  1      True
#  2      True
#  3     False
#  4      True
#  5      True
#  6      True
#  7      True
#  8      True
#  9      True
#  10     True
#  11     True
#  12     True
#  13     True
#  14     True
#  15     True
#  16    False
#  17     True
#  18     True
#  19    False
#  20     True
#  21    False
#  22     True
#  23     True
#  24     True
#  25     True
#  26     True
#  27    False
#  28     True
#  29     True
#  30     True
#  31     True
#  32     True
#  33     True
#  34     True
#  35     True
#  36     True
#  37    False
#  Name: attacker_outcome, dtype: bool]
